# %% [markdown]
# # House Prices: Advanced Regression Techniques
#
# Predict sales prices and practice feature engineering, RFs, and gradient boosting
#
# Link: <a href="https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data">Kaggle challenge</a>
#
# ### Libraries

# %%
# %pylab inline
import numpy
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from pylab import savefig

import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Helper Functions

# %%
def get_name_zone(val):
    return val

# %% [markdown]
# ### Global variables
#
# In this section, the variables that will be queried during the analysis will be initialized.

# %%
test = "dataset/test.csv"
train = "dataset/train.csv"

# %% [markdown]
# ### Importing datasets (train and test) to dataframe of pandas

# %%
ds = pandas.read_csv(train, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
ds.head()
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 0  1         60       RL          65    8450   Pave   NaN      Reg
# 1  2         20       RL          80    9600   Pave   NaN      Reg
# 2  3         60       RL          68   11250   Pave   NaN      IR1
# 3  4         70       RL          60    9550   Pave   NaN      IR1
# 4  5         60       RL          84   14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...    PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...           0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...           0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...           0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...           0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...           0    NaN   NaN         NaN       0
#
#   MoSold YrSold SaleType SaleCondition SalePrice
# 0      2   2008       WD        Normal    208500
# 1      5   2007       WD        Normal    181500
# 2      9   2008       WD        Normal    223500
# 3      2   2006       WD       Abnorml    140000
# 4     12   2008       WD        Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Getting informations about data

# %%
ds.shape
# Out:
# (1460, 81)

# %%
ds.describe()
# Out:
#           Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# count   1460       1460     1460        1201    1460   1460    91     1460
# unique  1460         15        5         110    1073      2     2        4
# top     1037         20       RL          60    7200   Pave  Grvl      Reg
# freq       1        536     1151         143      25   1454    50      925
#
#        LandContour Utilities    ...    PoolArea PoolQC  Fence MiscFeature  \
# count         1460      1460    ...        1460      7    281          54
# unique           4         2    ...           8      3      4           4
# top            Lvl    AllPub    ...           0     Gd  MnPrv        Shed
# freq          1311      1459    ...        1453      3    157          49
#
#        MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# count     1460   1460   1460     1460          1460      1460
# unique      21     12      5        9             6       663
# top          0      6   2009       WD        Normal    140000
# freq      1408    253    338     1267          1198        20
#
# [4 rows x 81 columns]

# %% [markdown]
# ### Checking the amount of null data in the file

# %%
for col in list(ds.columns.values):
        print ("Number of missing data on " + col + ":" ,ds[col].isnull().values.sum())
# Out:
# Number of missing data on Id: 0
# Number of missing data on MSSubClass: 0
# Number of missing data on MSZoning: 0
# Number of missing data on LotFrontage: 259
# Number of missing data on LotArea: 0
# Number of missing data on Street: 0
# Number of missing data on Alley: 1369
# Number of missing data on LotShape: 0
# Number of missing data on LandContour: 0
# Number of missing data on Utilities: 0
# Number of missing data on LotConfig: 0
# Number of missing data on LandSlope: 0
# Number of missing data on Neighborhood: 0
# Number of missing data on Condition1: 0
# Number of missing data on Condition2: 0
# Number of missing data on BldgType: 0
# Number of missing data on HouseStyle: 0
# Number of missing data on OverallQual: 0
# Number of missing data on OverallCond: 0
# Number of missing data on YearBuilt: 0
# Number of missing data on YearRemodAdd: 0
# Number of missing data on RoofStyle: 0
# Number of missing data on RoofMatl: 0
# Number of missing data on Exterior1st: 0
# Number of missing data on Exterior2nd: 0
# Number of missing data on MasVnrType: 8
# Number of missing data on MasVnrArea: 8
# Number of missing data on ExterQual: 0
# Number of missing data on ExterCond: 0
# Number of missing data on Foundation: 0
# Number of missing data on BsmtQual: 37
# Number of missing data on BsmtCond: 37
# Number of missing data on BsmtExposure: 38
# Number of missing data on BsmtFinType1: 37
# Number of missing data on BsmtFinSF1: 0
# Number of missing data on BsmtFinType2: 38
# Number of missing data on BsmtFinSF2: 0
# Number of missing data on BsmtUnfSF: 0
# Number of missing data on TotalBsmtSF: 0
# Number of missing data on Heating: 0
# Number of missing data on HeatingQC: 0
# Number of missing data on CentralAir: 0
# Number of missing data on Electrical: 1
# Number of missing data on 1stFlrSF: 0
# Number of missing data on 2ndFlrSF: 0
# Number of missing data on LowQualFinSF: 0
# Number of missing data on GrLivArea: 0
# Number of missing data on BsmtFullBath: 0
# Number of missing data on BsmtHalfBath: 0
# Number of missing data on FullBath: 0
# Number of missing data on HalfBath: 0
# Number of missing data on BedroomAbvGr: 0
# Number of missing data on KitchenAbvGr: 0
# Number of missing data on KitchenQual: 0
# Number of missing data on TotRmsAbvGrd: 0
# Number of missing data on Functional: 0
# Number of missing data on Fireplaces: 0
# Number of missing data on FireplaceQu: 690
# Number of missing data on GarageType: 81
# Number of missing data on GarageYrBlt: 81
# Number of missing data on GarageFinish: 81
# Number of missing data on GarageCars: 0
# Number of missing data on GarageArea: 0
# Number of missing data on GarageQual: 81
# Number of missing data on GarageCond: 81
# Number of missing data on PavedDrive: 0
# Number of missing data on WoodDeckSF: 0
# Number of missing data on OpenPorchSF: 0
# Number of missing data on EnclosedPorch: 0
# Number of missing data on 3SsnPorch: 0
# Number of missing data on ScreenPorch: 0
# Number of missing data on PoolArea: 0
# Number of missing data on PoolQC: 1453
# Number of missing data on Fence: 1179
# Number of missing data on MiscFeature: 1406
# Number of missing data on MiscVal: 0
# Number of missing data on MoSold: 0
# Number of missing data on YrSold: 0
# Number of missing data on SaleType: 0
# Number of missing data on SaleCondition: 0
# Number of missing data on SalePrice: 0

# %% [markdown]
# ### Verifying the relation of zones with the average price

# %%
# Converting data type
ds[['SalePrice']] = ds[['SalePrice']].apply(pd.to_numeric)

# Showing results
ds.groupby('MSZoning')['SalePrice']\
    .agg(["mean", "std"])
# Out:
#                    mean           std
# MSZoning
# C (all)    74528.000000  33791.092031
# FV        214014.061538  52369.662067
# RH        131558.375000  35714.118435
# RL        191004.994787  80766.341319
# RM        126316.830275  48521.689833

# %%
ax = ds[['SalePrice', 'MSZoning']].boxplot(by='MSZoning', figsize=(10, 6), rot=90)
ax.set_xlabel('Zones')
ax.set_ylabel('Price')
ax.set_title('Prices by zone');
plt.suptitle('')  # Getting rid of pandas-generated boxplot title
# Out:
# Text(0.5,0.98,'')
